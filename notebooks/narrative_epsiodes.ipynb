# %%
# a RELiC-type approach to retrieving narrative episodes. We take passages which have a cross-reference between them, apply a contrastive loss to their embeddings
# and then use out-of-domain "text" queries with descriptions of type-scenes. 

# let's try this.
# things I would need to figure out, taking a context window around the cross-reference, and then applying a contrastive loss to the embeddings of the two passages.

# first let's write a function to parse cross_references.txt

# %%
## Helpers
import re

book2id = {k : i for i, k in enumerate("""GEN
EXO
LEV
NUM
DEU
JOS
JDG
RUT
1SA
2SA
1KI
2KI
1CH
2CH
EZR
NEH
EST
JOB
PSA
PRO
ECC
SOS
ISA
JER
LAM
EZE
DAN
HOS
JOE
AMO
OBA
JON
MIC
NAH
HAB
ZEP
HAG
ZEC
MAL
MAT
MAR
LUK
JOH
ACT
ROM
1CO
2CO
GAL
EPH
PHP
COL
1TH
2TH
1TI
2TI
TIT
PHM
HEB
JAM
1PE
2PE
1JO
2JO
3JO
JDE
REV""".split())}
id2book = {i : b for b, i in book2id.items()}

mapping = {
    "1KGS" : "1KI",
    "2KGS" : "2KI",    
    "JAS" : "JAM",
    "JUDG" : "JDG",
    "PS" : "PSA",
    "JUDE" : "JDE",
    "SONG" : "SOS",
    "PHIL" : "PHP",
    "PHLM" : "PHM",    
    "SON" : "SOS",
    "PHI" : "PHP",
    "JUD" : "JDE"
}

class Location(dict):
    def __init__(self, value):
        if isinstance(value, str):
            book, chapter, verse = re.sub(r"^b\.", "", value).upper().split(".")
            book3 = mapping.get(book, book[:3])
            assert book3 in book2id
            self["book"] = book3
            self["chapter"] = int(chapter)
            self["verse"] = int(verse)
        elif isinstance(value, (dict,)):
            for k in ["book", "chapter", "verse"]:
                self[k] = value[k]
        else:
            raise Exception("Not sure how to turn '{}' into a location".format(value))

    def __cmp__(self, other):
        a = (book2id[self["book"]], self["chapter"], self["verse"])
        b = (book2id[other["book"]], other["chapter"], other["verse"])
        return -1 if a < b else 0 if a == b else 1

    def __gt__(self, other):
        return (book2id[self["book"]], self["chapter"], self["verse"]) > (book2id[other["book"]], other["chapter"], other["verse"])

    def __le__(self, other):
        return (book2id[self["book"]], self["chapter"], self["verse"]) <= (book2id[other["book"]], other["chapter"], other["verse"])

    def __lt__(self, other):
        return (book2id[self["book"]], self["chapter"], self["verse"]) < (book2id[other["book"]], other["chapter"], other["verse"])    

    def __hash__(self):
        return hash(repr(self))

# %%
import pandas as pd

cross_refs = pd.read_csv('../data/cross_references.txt', sep='\t', header=0)
# keep only those lines for which votes > 50
votes_thres = 50
cross_refs = cross_refs[cross_refs['Votes'] > votes_thres]

# %%
cross_refs.head()
# Out:
#    From Verse           To Verse  Votes
# 5     Gen.1.1            Neh.9.6     56
# 10    Gen.1.1         Exod.20.11     88
# 18    Gen.1.1  John.1.1-John.1.3    191
# 19    Gen.1.1          Isa.45.18    141
# 23    Gen.1.1           Heb.11.3    167

# %%
# we can see some of the cross-references are to a span of verses, we will take the first verse of that span.
# 436 cross-refs link to a span of at least 2 verses. 436 one-to-many references
cross_refs['To Verse'] = cross_refs['To Verse'].apply(lambda x: x.split("-")[0])
# check if that worked
sum(cross_refs['To Verse'].apply(lambda x: len(x.split("-")) > 1))
# good, no more multi-verse references
# Out:
# 0

# %%
# modified from Tom's script
books = set()
labels = set()
golds = {}
num_golds = 0

for i, row in cross_refs.iterrows():
    a = Location(row['From Verse'])
    b = Location(row['To Verse'])
    labels.add(a)
    labels.add(b)
    books.add(a["book"])
    books.add(b["book"])
    if a < b:
        src, tgt = a, b
    else:
        src, tgt = b, a
    key = (src, tgt)
    golds[src] = golds.get(src, {})
    
    golds[src][tgt] = row['Votes']
    num_golds += 1

# %%
golds
# Out:
# {{'book': 'GEN',
#   'chapter': 1,
#   'verse': 1}: {{'book': 'NEH', 'chapter': 9, 'verse': 6}: 56, {'book': 'EXO',
#    'chapter': 20,
#    'verse': 11}: 88, {'book': 'JOH',
#    'chapter': 1,
#    'verse': 1}: 143, {'book': 'ISA', 'chapter': 45, 'verse': 18}: 141, {'book': 'HEB',
#    'chapter': 11,
#    'verse': 3}: 167, {'book': 'JOB',
#    'chapter': 38,
#    'verse': 4}: 88, {'book': 'ACT', 'chapter': 17, 'verse': 24}: 78, {'book': '2PE',
#    'chapter': 3,
#    'verse': 5}: 58, {'book': 'ISA',
#    'chapter': 44,
#    'verse': 24}: 52, {'book': 'ISA', 'chapter': 42, 'verse': 5}: 88, {'book': 'COL',
#    'chapter': 1,
#    'verse': 16}: 84, {'book': 'REV',
#    'chapter': 4,
#    'verse': 11}: 114, {'book': 'HEB', 'chapter': 1, 'verse': 10}: 105},
#  {'book': 'GEN',
#   'chapter': 2,
#   'verse': 24}: {{'book': 'MAT', 'chapter': 19, 'verse': 3}: 53},
#  {'book': 'GEN',
#   'chapter': 3,
#   'verse': 15}: {{'book': 'ROM', 'chapter': 16, 'verse': 20}: 77},
#  {'book': 'GEN',
#   'chapter': 15,
#   'verse': 6}: {{'book': 'JAM', 'chapter': 2, 'verse': 23}: 52},
#  {'book': 'GEN',
#   'chapter': 50,
#   'verse': 20}: {{'book': 'PSA', 'chapter': 119, 'verse': 71}: 60,
#   {'book': 'ROM', 'chapter': 8, 'verse': 28}: 214},
#  {'book': 'EXO',
#   'chapter': 14,
#   'verse': 14}: {{'book': 'DEU',
#    'chapter': 3,
#    'verse': 22}: 85, {'book': 'DEU',
#    'chapter': 20,
#    'verse': 4}: 67, {'book': 'JOS', 'chapter': 23, 'verse': 10}: 345},
#  {'book': 'EXO',
#   'chapter': 15,
#   'verse': 11}: {{'book': 'PSA',
#    'chapter': 89,
#    'verse': 5}: 56, {'book': '1KI', 'chapter': 8, 'verse': 23}: 60},
#  {'book': 'EXO',
#   'chapter': 34,
#   'verse': 6}: {{'book': 'NEH', 'chapter': 9, 'verse': 17}: 57, {'book': 'PSA',
#    'chapter': 103,
#    'verse': 8}: 69, {'book': 'PSA',
#    'chapter': 86,
#    'verse': 15}: 86, {'book': 'JOE', 'chapter': 2, 'verse': 13}: 84, {'book': 'PSA',
#    'chapter': 145,
#    'verse': 8}: 65},
#  {'book': 'NUM',
#   'chapter': 23,
#   'verse': 19}: {{'book': 'JAM',
#    'chapter': 1,
#    'verse': 17}: 57, {'book': '1SA', 'chapter': 15, 'verse': 29}: 54, {'book': 'MAL',
#    'chapter': 3,
#    'verse': 6}: 57, {'book': 'MAT', 'chapter': 24, 'verse': 35}: 212},
#  {'book': 'DEU',
#   'chapter': 4,
#   'verse': 9}: {{'book': 'DEU',
#    'chapter': 32,
#    'verse': 46}: 79, {'book': 'PRO', 'chapter': 4, 'verse': 20}: 54, {'book': 'PSA',
#    'chapter': 78,
#    'verse': 3}: 112, {'book': 'DEU',
#    'chapter': 29,
#    'verse': 29}: 59, {'book': 'EPH', 'chapter': 6, 'verse': 4}: 71, {'book': 'DEU',
#    'chapter': 6,
#    'verse': 7}: 185, {'book': 'DEU',
#    'chapter': 11,
#    'verse': 19}: 139, {'book': 'PRO', 'chapter': 4, 'verse': 23}: 186},
#  {'book': 'GEN',
#   'chapter': 18,
#   'verse': 19}: {{'book': 'DEU', 'chapter': 4, 'verse': 9}: 94},
#  {'book': 'EXO',
#   'chapter': 13,
#   'verse': 8}: {{'book': 'DEU', 'chapter': 4, 'verse': 9}: 52},
#  {'book': 'DEU',
#   'chapter': 6,
#   'verse': 5}: {{'book': 'LUK', 'chapter': 10, 'verse': 27}: 62,
#   {'book': 'MAR', 'chapter': 12, 'verse': 30}: 82,
#   {'book': 'MAT', 'chapter': 22, 'verse': 37}: 64},
#  {'book': 'DEU',
#   'chapter': 8,
#   'verse': 18}: {{'book': 'PRO', 'chapter': 10, 'verse': 22}: 64},
#  {'book': 'LEV',
#   'chapter': 26,
#   'verse': 3}: {{'book': 'DEU', 'chapter': 11, 'verse': 27}: 52},
#  {'book': 'DEU',
#   'chapter': 11,
#   'verse': 27}: {{'book': 'LUK', 'chapter': 11, 'verse': 28}: 57,
#   {'book': 'ISA', 'chapter': 3, 'verse': 10}: 64,
#   {'book': 'DEU', 'chapter': 28, 'verse': 1}: 83,
#   {'book': 'ISA', 'chapter': 1, 'verse': 19}: 96},
#  {'book': 'EXO',
#   'chapter': 23,
#   'verse': 14}: {{'book': 'DEU', 'chapter': 16, 'verse': 16}: 52},
#  {'book': 'DEU',
#   'chapter': 16,
#   'verse': 16}: {{'book': 'PRO', 'chapter': 3, 'verse': 9}: 77,
#   {'book': 'PSA', 'chapter': 96, 'verse': 8}: 68},
#  {'book': 'DEU',
#   'chapter': 31,
#   'verse': 6}: {{'book': 'JOS', 'chapter': 1, 'verse': 9}: 73, {'book': 'ISA',
#    'chapter': 41,
#    'verse': 10}: 339, {'book': 'HEB', 'chapter': 13, 'verse': 5}: 65},
#  {'book': 'JOS',
#   'chapter': 1,
#   'verse': 8}: {{'book': 'PSA',
#    'chapter': 119,
#    'verse': 11}: 61, {'book': 'COL', 'chapter': 3, 'verse': 16}: 89, {'book': 'PSA',
#    'chapter': 19,
#    'verse': 14}: 113, {'book': 'JOH',
#    'chapter': 14,
#    'verse': 21}: 82, {'book': 'JAM', 'chapter': 1, 'verse': 22}: 63, {'book': 'MAT',
#    'chapter': 7,
#    'verse': 24}: 72, {'book': 'PSA',
#    'chapter': 119,
#    'verse': 97}: 52, {'book': 'LUK', 'chapter': 11, 'verse': 28}: 76, {'book': 'PRO',
#    'chapter': 3,
#    'verse': 1}: 88, {'book': 'PSA',
#    'chapter': 119,
#    'verse': 15}: 141, {'book': 'PSA', 'chapter': 1, 'verse': 1}: 54, {'book': 'PSA',
#    'chapter': 1,
#    'verse': 2}: 51},
#  {'book': 'DEU',
#   'chapter': 29,
#   'verse': 9}: {{'book': 'JOS', 'chapter': 1, 'verse': 8}: 77},
#  {'book': 'DEU',
#   'chapter': 6,
#   'verse': 6}: {{'book': 'JOS', 'chapter': 1, 'verse': 8}: 78},
#  {'book': 'DEU',
#   'chapter': 20,
#   'verse': 1}: {{'book': 'JOS', 'chapter': 1, 'verse': 9}: 72,
#   {'book': 'ISA', 'chapter': 41, 'verse': 10}: 153},
#  {'book': 'JOS',
#   'chapter': 1,
#   'verse': 6}: {{'book': 'JOS', 'chapter': 1, 'verse': 9}: 98, {'book': '1CO',
#    'chapter': 16,
#    'verse': 13}: 80},
#  {'book': 'JOS',
#   'chapter': 1,
#   'verse': 9}: {{'book': 'PSA', 'chapter': 27, 'verse': 1}: 85, {'book': 'JER',
#    'chapter': 1,
#    'verse': 7}: 108, {'book': 'ISA',
#    'chapter': 43,
#    'verse': 1}: 58, {'book': 'ISA', 'chapter': 43, 'verse': 5}: 55, {'book': 'PSA',
#    'chapter': 46,
#    'verse': 7}: 65, {'book': 'ISA',
#    'chapter': 41,
#    'verse': 10}: 540, {'book': 'ISA', 'chapter': 43, 'verse': 2}: 53, {'book': '1CO',
#    'chapter': 16,
#    'verse': 13}: 208, {'book': '2CO',
#    'chapter': 12,
#    'verse': 9}: 57, {'book': 'EPH', 'chapter': 6, 'verse': 10}: 62},
#  {'book': 'GEN',
#   'chapter': 28,
#   'verse': 15}: {{'book': 'JOS', 'chapter': 1, 'verse': 9}: 135},
#  {'book': 'DEU',
#   'chapter': 31,
#   'verse': 7}: {{'book': 'JOS', 'chapter': 1, 'verse': 9}: 64},
#  {'book': 'JOS',
#   'chapter': 23,
#   'verse': 10}: {{'book': '2SA', 'chapter': 23, 'verse': 8}: 124,
#   {'book': 'JDG', 'chapter': 15, 'verse': 15}: 148,
#   {'book': 'PSA', 'chapter': 46, 'verse': 7}: 227,
#   {'book': 'PSA', 'chapter': 35, 'verse': 1}: 310,
#   {'book': '1SA', 'chapter': 14, 'verse': 6}: 184,
#   {'book': 'JDG', 'chapter': 3, 'verse': 31}: 117,
#   {'book': 'PSA', 'chapter': 44, 'verse': 4}: 197,
#   {'book': '1SA', 'chapter': 14, 'verse': 12}: 114,
#   {'book': 'JDG', 'chapter': 7, 'verse': 19}: 119,
#   {'book': 'ROM', 'chapter': 8, 'verse': 31}: 279},
#  {'book': 'JOS',
#   'chapter': 23,
#   'verse': 3}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 212},
#  {'book': 'DEU',
#   'chapter': 3,
#   'verse': 22}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 400},
#  {'book': 'DEU',
#   'chapter': 20,
#   'verse': 4}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 301},
#  {'book': 'JOS',
#   'chapter': 10,
#   'verse': 42}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 172},
#  {'book': 'EXO',
#   'chapter': 23,
#   'verse': 27}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 172},
#  {'book': 'DEU',
#   'chapter': 32,
#   'verse': 30}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 676},
#  {'book': 'LEV',
#   'chapter': 26,
#   'verse': 8}: {{'book': 'JOS', 'chapter': 23, 'verse': 10}: 560},
#  {'book': 'JOS',
#   'chapter': 24,
#   'verse': 15}: {{'book': '1KI', 'chapter': 18, 'verse': 21}: 83,
#   {'book': 'JOH', 'chapter': 6, 'verse': 67}: 56},
#  {'book': 'DEU',
#   'chapter': 13,
#   'verse': 4}: {{'book': '1SA', 'chapter': 7, 'verse': 3}: 98},
#  {'book': '1SA',
#   'chapter': 7,
#   'verse': 3}: {{'book': 'MAT', 'chapter': 4, 'verse': 10}: 81,
#   {'book': 'LUK', 'chapter': 4, 'verse': 8}: 142},
#  {'book': 'DEU',
#   'chapter': 6,
#   'verse': 13}: {{'book': '1SA', 'chapter': 7, 'verse': 3}: 65},
#  {'book': '1SA',
#   'chapter': 15,
#   'verse': 22}: {{'book': 'MAT', 'chapter': 5, 'verse': 24}: 80,
#   {'book': 'JER', 'chapter': 11, 'verse': 7}: 67,
#   {'book': 'ISA', 'chapter': 1, 'verse': 11}: 142,
#   {'book': 'MIC', 'chapter': 6, 'verse': 6}: 183,
#   {'book': 'PSA', 'chapter': 51, 'verse': 16}: 262,
#   {'book': 'JER', 'chapter': 26, 'verse': 13}: 76,
#   {'book': 'MAR', 'chapter': 12, 'verse': 33}: 208,
#   {'book': 'AMO', 'chapter': 5, 'verse': 21}: 212,
#   {'book': 'PRO', 'chapter': 21, 'verse': 3}: 247,
#   {'book': 'MAT', 'chapter': 12, 'verse': 7}: 132,
#   {'book': 'ECC', 'chapter': 5, 'verse': 1}: 138,
#   {'book': 'JER', 'chapter': 7, 'verse': 22}: 171,
#   {'book': 'PSA', 'chapter': 50, 'verse': 8}: 85,
#   {'book': 'MAT', 'chapter': 9, 'verse': 13}: 195,
#   {'book': 'HEB', 'chapter': 10, 'verse': 4}: 122,
#   {'book': 'JER', 'chapter': 11, 'verse': 4}: 56,
#   {'book': 'PSA', 'chapter': 40, 'verse': 6}: 148,
#   {'book': 'HOS', 'chapter': 6, 'verse': 6}: 309,
#   {'book': 'MAT', 'chapter': 23, 'verse': 23}: 103,
#   {'book': 'MIC', 'chapter': 6, 'verse': 8}: 51},
#  {'book': 'EXO',
#   'chapter': 19,
#   'verse': 5}: {{'book': '1SA',
#    'chapter': 15,
#    'verse': 22}: 64, {'book': '1PE', 'chapter': 2, 'verse': 9}: 99},
#  {'book': '1SA',
#   'chapter': 16,
#   'verse': 7}: {{'book': 'JER',
#    'chapter': 17,
#    'verse': 10}: 59, {'book': 'JOH',
#    'chapter': 7,
#    'verse': 24}: 73, {'book': '1CH', 'chapter': 28, 'verse': 9}: 74},
#  {'book': '1SA',
#   'chapter': 23,
#   'verse': 16}: {{'book': 'LUK',
#    'chapter': 22,
#    'verse': 32}: 61, {'book': 'NEH',
#    'chapter': 2,
#    'verse': 18}: 54, {'book': 'EPH',
#    'chapter': 6,
#    'verse': 10}: 72, {'book': 'ISA',
#    'chapter': 35,
#    'verse': 3}: 157, {'book': '1SA',
#    'chapter': 30,
#    'verse': 6}: 56, {'book': 'JOB',
#    'chapter': 4,
#    'verse': 3}: 109, {'book': 'HEB',
#    'chapter': 12,
#    'verse': 12}: 156, {'book': '2TI',
#    'chapter': 2,
#    'verse': 1}: 76, {'book': 'LUK', 'chapter': 22, 'verse': 43}: 54},
#  {'book': '2SA',
#   'chapter': 7,
#   'verse': 18}: {{'book': 'PSA',
#    'chapter': 8,
#    'verse': 4}: 106, {'book': '1CH', 'chapter': 17, 'verse': 16}: 78},
#  {'book': '1SA',
#   'chapter': 18,
#   'verse': 18}: {{'book': '2SA', 'chapter': 7, 'verse': 18}: 53},
#  {'book': '1CH',
#   'chapter': 28,
#   'verse': 9}: {{'book': 'PSA', 'chapter': 139, 'verse': 2}: 59,
#   {'book': 'PSA', 'chapter': 9, 'verse': 10}: 85,
#   {'book': 'MAT', 'chapter': 7, 'verse': 7}: 130,
#   {'book': 'JER', 'chapter': 24, 'verse': 7}: 108,
#   {'book': 'JOH', 'chapter': 4, 'verse': 24}: 71,
#   {'book': 'PRO', 'chapter': 2, 'verse': 1}: 99,
#   {'book': 'JER', 'chapter': 29, 'verse': 13}: 288,
#   {'book': 'JER', 'chapter': 17, 'verse': 10}: 62,
#   {'book': '2CH', 'chapter': 15, 'verse': 2}: 92,
#   {'book': 'ISA', 'chapter': 55, 'verse': 6}: 129,
#   {'book': 'JAM', 'chapter': 4, 'verse': 8}: 142},
#  {'book': '1KI',
#   'chapter': 8,
#   'verse': 61}: {{'book': '1CH', 'chapter': 28, 'verse': 9}: 100},
#  {'book': '2CH',
#   'chapter': 7,
#   'verse': 14}: {{'book': 'JER', 'chapter': 33, 'verse': 6}: 78,
#   {'book': 'ISA', 'chapter': 55, 'verse': 6}: 143,
#   {'book': 'JAM', 'chapter': 4, 'verse': 9}: 165,
#   {'book': 'PRO', 'chapter': 28, 'verse': 13}: 103,
#   {'book': 'EZE', 'chapter': 33, 'verse': 11}: 57,
#   {'book': 'LAM', 'chapter': 3, 'verse': 40}: 155,
#   {'book': '2CH', 'chapter': 33, 'verse': 12}: 69},
#  {'book': '2CH',
#   'chapter': 6,
#   'verse': 27}: {{'book': '2CH', 'chapter': 7, 'verse': 14}: 64},
#  {'book': '2CH',
#   'chapter': 6,
#   'verse': 37}: {{'book': '2CH', 'chapter': 7, 'verse': 14}: 104},
#  {'book': 'LEV',
#   'chapter': 26,
#   'verse': 40}: {{'book': '2CH', 'chapter': 7, 'verse': 14}: 58},
#  {'book': 'DEU',
#   'chapter': 4,
#   'verse': 29}: {{'book': '2CH', 'chapter': 7, 'verse': 14}: 75,
#   {'book': 'JER', 'chapter': 29, 'verse': 13}: 52,
#   {'book': 'JER', 'chapter': 33, 'verse': 3}: 78},
#  {'book': '2CH',
#   'chapter': 16,
#   'verse': 9}: {{'book': '1PE', 'chapter': 3, 'verse': 12}: 57},
#  {'book': 'PSA',
#   'chapter': 1,
#   'verse': 1}: {{'book': 'JER', 'chapter': 15, 'verse': 17}: 84,
#   {'book': 'LUK', 'chapter': 11, 'verse': 28}: 60,
#   {'book': 'MAT', 'chapter': 7, 'verse': 13}: 61,
#   {'book': 'PSA', 'chapter': 1, 'verse': 6}: 58,
#   {'book': 'PSA', 'chapter': 26, 'verse': 4}: 167,
#   {'book': 'PSA', 'chapter': 119, 'verse': 1}: 76,
#   {'book': 'PRO', 'chapter': 4, 'verse': 14}: 139,
#   {'book': 'PRO', 'chapter': 13, 'verse': 20}: 95},
#  {'book': 'PSA',
#   'chapter': 1,
#   'verse': 3}: {{'book': 'JER', 'chapter': 17, 'verse': 8}: 90},
#  {'book': 'PSA',
#   'chapter': 3,
#   'verse': 3}: {{'book': 'PSA', 'chapter': 27, 'verse': 6}: 52},
#  {'book': 'PSA',
#   'chapter': 14,
#   'verse': 1}: {{'book': 'PSA', 'chapter': 14, 'verse': 3}: 58},
#  {'book': 'PSA',
#   'chapter': 14,
#   'verse': 3}: {{'book': 'ROM', 'chapter': 3, 'verse': 10}: 119,
#   {'book': 'ISA', 'chapter': 64, 'verse': 6}: 85,
#   {'book': 'ROM', 'chapter': 3, 'verse': 23}: 58,
#   {'book': 'ISA', 'chapter': 53, 'verse': 6}: 86},
#  {'book': 'PSA',
#   'chapter': 16,
#   'verse': 11}: {{'book': 'ACT',
#    'chapter': 2,
#    'verse': 28}: 59, {'book': 'PSA', 'chapter': 31, 'verse': 19}: 81},
#  {'book': 'PSA',
#   'chapter': 23,
#   'verse': 1}: {{'book': 'JOH',
#    'chapter': 10,
#    'verse': 27}: 144, {'book': 'HEB',
#    'chapter': 13,
#    'verse': 5}: 70, {'book': '1PE',
#    'chapter': 5,
#    'verse': 4}: 58, {'book': 'EZE',
#    'chapter': 34,
#    'verse': 23}: 52, {'book': 'MAT',
#    'chapter': 6,
#    'verse': 33}: 109, {'book': 'ISA',
#    'chapter': 40,
#    'verse': 11}: 153, {'book': 'PHP',
#    'chapter': 4,
#    'verse': 19}: 55, {'book': 'PSA',
#    'chapter': 84,
#    'verse': 11}: 51, {'book': '1PE',
#    'chapter': 2,
#    'verse': 25}: 83, {'book': 'EZE',
#    'chapter': 34,
#    'verse': 11}: 71, {'book': 'JOH',
#    'chapter': 10,
#    'verse': 14}: 111, {'book': 'JOH',
#    'chapter': 10,
#    'verse': 11}: 200, {'book': 'REV',
#    'chapter': 7,
#    'verse': 17}: 101, {'book': 'PSA', 'chapter': 34, 'verse': 9}: 56},
#  {'book': 'PSA',
#   'chapter': 3,
#   'verse': 6}: {{'book': 'PSA', 'chapter': 23, 'verse': 4}: 52},
#  {'book': 'PSA',
#   'chapter': 23,
#   'verse': 4}: {{'book': 'PSA', 'chapter': 138, 'verse': 7}: 72,
#   {'book': 'ISA', 'chapter': 41, 'verse': 10}: 102,
#   {'book': 'PSA', 'chapter': 118, 'verse': 6}: 79},
#  {'book': 'PSA',
#   'chapter': 25,
#   'verse': 3}: {{'book': 'MIC', 'chapter': 7, 'verse': 7}: 51, {'book': 'ISA',
#    'chapter': 49,
#    'verse': 23}: 60, {'book': 'LAM',
#    'chapter': 3,
#    'verse': 25}: 66, {'book': 'ISA', 'chapter': 40, 'verse': 31}: 58, {'book': 'ISA',
#    'chapter': 45,
#    'verse': 17}: 212},
#  {'book': 'PSA',
#   'chapter': 27,
#   'verse': 1}: {{'book': 'PSA',
#    'chapter': 118,
#    'verse': 6}: 64, {'book': 'HEB', 'chapter': 13, 'verse': 6}: 200, {'book': 'PRO',
#    'chapter': 28,
#    'verse': 1}: 63, {'book': 'ISA',
#    'chapter': 41,
#    'verse': 10}: 219, {'book': 'ROM', 'chapter': 8, 'verse': 31}: 74},
#  {'book': 'PSA',
#   'chapter': 27,
#   'verse': 14}: {{'book': 'ISA',
#    'chapter': 40,
#    'verse': 31}: 67, {'book': 'PRO',
#    'chapter': 20,
#    'verse': 22}: 57, {'book': '1CO', 'chapter': 16, 'verse': 13}: 97},
#  {'book': 'PSA',
#   'chapter': 31,
#   'verse': 19}: {{'book': 'ISA',
#    'chapter': 64,
#    'verse': 4}: 206, {'book': 'COL',
#    'chapter': 3,
#    'verse': 2}: 86, {'book': 'JAM',
#    'chapter': 2,
#    'verse': 5}: 78, {'book': 'LAM',
#    'chapter': 3,
#    'verse': 23}: 116, {'book': '2CO',
#    'chapter': 5,
#    'verse': 5}: 57, {'book': '1PE',
#    'chapter': 1,
#    'verse': 4}: 91, {'book': 'PSA',
#    'chapter': 36,
#    'verse': 7}: 53, {'book': 'PSA',
#    'chapter': 145,
#    'verse': 7}: 52, {'book': 'PSA',
#    'chapter': 126,
#    'verse': 2}: 67, {'book': '1CO',
#    'chapter': 2,
#    'verse': 9}: 67, {'book': '1JO', 'chapter': 3, 'verse': 1}: 60},
#  {'book': 'PSA',
#   'chapter': 23,
#   'verse': 5}: {{'book': 'PSA', 'chapter': 31, 'verse': 19}: 57},
#  {'book': 'PSA',
#   'chapter': 32,
#   'verse': 8}: {{'book': 'MAT', 'chapter': 11, 'verse': 29}: 51,
#   {'book': 'PRO', 'chapter': 3, 'verse': 5}: 87,
#   {'book': 'PSA', 'chapter': 33, 'verse': 18}: 64,
#   {'book': 'PRO', 'chapter': 3, 'verse': 6}: 100,
#   {'book': 'ISA', 'chapter': 30, 'verse': 21}: 117,
#   {'book': 'ISA', 'chapter': 48, 'verse': 17}: 186},
#  {'book': 'PSA',
#   'chapter': 25,
#   'verse': 8}: {{'book': 'PSA', 'chapter': 32, 'verse': 8}: 59, {'book': 'ISA',
#    'chapter': 30,
#    'verse': 21}: 52, {'book': 'ISA', 'chapter': 48, 'verse': 17}: 54},
#  {'book': 'PSA',
#   'chapter': 33,
#   'verse': 10}: {{'book': 'ISA',
#    'chapter': 44,
#    'verse': 23}: 64, {'book': 'ISA', 'chapter': 19, 'verse': 11}: 53, {'book': 'ISA',
#    'chapter': 44,
#    'verse': 25}: 140, {'book': 'PSA',
#    'chapter': 140,
#    'verse': 8}: 95, {'book': 'ISA', 'chapter': 7, 'verse': 5}: 80, {'book': 'ISA',
#    'chapter': 8,
#    'verse': 9}: 96, {'book': 'PRO',
#    'chapter': 21,
#    'verse': 30}: 126, {'book': 'ISA', 'chapter': 19, 'verse': 3}: 65},
#  {'book': 'PSA',
#   'chapter': 21,
#   'verse': 11}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 190},
#  {'book': 'EXO',
#   'chapter': 1,
#   'verse': 10}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 58},
#  {'book': '2SA',
#   'chapter': 17,
#   'verse': 23}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 75},
#  {'book': 'PSA',
#   'chapter': 9,
#   'verse': 15}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 85},
#  {'book': '2SA',
#   'chapter': 15,
#   'verse': 31}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 109},
#  {'book': 'PSA',
#   'chapter': 2,
#   'verse': 1}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 93},
#  {'book': 'JOB',
#   'chapter': 5,
#   'verse': 12}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 165},
#  {'book': '2SA',
#   'chapter': 17,
#   'verse': 14}: {{'book': 'PSA', 'chapter': 33, 'verse': 10}: 62},
#  {'book': 'PSA',
#   'chapter': 34,
#   'verse': 4}: {{'book': 'MAT', 'chapter': 7, 'verse': 7}: 77,
#   {'book': 'PSA', 'chapter': 116, 'verse': 1}: 84,
#   {'book': 'PSA', 'chapter': 56, 'verse': 3}: 65,
#   {'book': '2TI', 'chapter': 1, 'verse': 7}: 63,
#   {'book': 'LUK', 'chapter': 11, 'verse': 9}: 79},
#  {'book': 'PSA',
#   'chapter': 18,
#   'verse': 6}: {{'book': 'PSA', 'chapter': 34, 'verse': 4}: 111},
#  {'book': 'PSA',
#   'chapter': 34,
#   'verse': 8}: {{'book': '1PE', 'chapter': 2, 'verse': 2}: 71,
#   {'book': 'PSA', 'chapter': 119, 'verse': 103}: 71,
#   {'book': 'HEB', 'chapter': 6, 'verse': 4}: 82},
#  {'book': 'PSA',
#   'chapter': 34,
#   'verse': 14}: {{'book': 'PSA', 'chapter': 37, 'verse': 27}: 77},
#  {'book': 'PSA',
#   'chapter': 34,
#   'verse': 18}: {{'book': 'PSA', 'chapter': 147, 'verse': 3}: 71,
#   {'book': 'PSA', 'chapter': 145, 'verse': 18}: 56,
#   {'book': 'ISA', 'chapter': 61, 'verse': 1}: 58,
#   {'book': 'MAT', 'chapter': 5, 'verse': 3}: 60},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 4}: {{'book': 'PSA',
#    'chapter': 145,
#    'verse': 19}: 166, {'book': 'PSA',
#    'chapter': 104,
#    'verse': 34}: 60, {'book': '1JO',
#    'chapter': 5,
#    'verse': 14}: 111, {'book': 'JOH',
#    'chapter': 15,
#    'verse': 7}: 101, {'book': 'JOH',
#    'chapter': 15,
#    'verse': 16}: 116, {'book': 'ISA',
#    'chapter': 58,
#    'verse': 14}: 122, {'book': '1PE',
#    'chapter': 1,
#    'verse': 8}: 65, {'book': 'PRO', 'chapter': 16, 'verse': 3}: 154},
#  {'book': 'JOB',
#   'chapter': 22,
#   'verse': 26}: {{'book': 'PSA', 'chapter': 37, 'verse': 4}: 74},
#  {'book': 'PSA',
#   'chapter': 21,
#   'verse': 1}: {{'book': 'PSA', 'chapter': 37, 'verse': 4}: 76},
#  {'book': 'JOB',
#   'chapter': 27,
#   'verse': 10}: {{'book': 'PSA', 'chapter': 37, 'verse': 4}: 54},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 5}: {{'book': 'PRO', 'chapter': 16, 'verse': 3}: 58,
#   {'book': 'PSA', 'chapter': 55, 'verse': 22}: 86,
#   {'book': 'PRO', 'chapter': 3, 'verse': 5}: 437,
#   {'book': '1PE', 'chapter': 5, 'verse': 7}: 131},
#  {'book': 'PSA',
#   'chapter': 46,
#   'verse': 1}: {{'book': 'PSA', 'chapter': 62, 'verse': 7}: 71, {'book': 'PSA',
#    'chapter': 91,
#    'verse': 1}: 56, {'book': 'PSA',
#    'chapter': 145,
#    'verse': 18}: 78, {'book': 'PRO', 'chapter': 18, 'verse': 10}: 62, {'book': 'ISA',
#    'chapter': 41,
#    'verse': 10}: 92},
#  {'book': 'PSA',
#   'chapter': 9,
#   'verse': 9}: {{'book': 'PSA', 'chapter': 46, 'verse': 1}: 73},
#  {'book': 'PSA',
#   'chapter': 46,
#   'verse': 10}: {{'book': 'PSA', 'chapter': 100, 'verse': 3}: 115,
#   {'book': 'EZE', 'chapter': 38, 'verse': 23}: 53,
#   {'book': 'PSA', 'chapter': 83, 'verse': 18}: 56,
#   {'book': 'HAB', 'chapter': 2, 'verse': 20}: 75,
#   {'book': 'ZEC', 'chapter': 2, 'verse': 13}: 57},
#  {'book': 'PSA',
#   'chapter': 51,
#   'verse': 10}: {{'book': 'EPH',
#    'chapter': 4,
#    'verse': 22}: 78, {'book': 'ROM', 'chapter': 12, 'verse': 2}: 87, {'book': '2CO',
#    'chapter': 5,
#    'verse': 17}: 111, {'book': 'EZE',
#    'chapter': 18,
#    'verse': 31}: 60, {'book': 'EZE', 'chapter': 11, 'verse': 19}: 109, {'book': 'MAT',
#    'chapter': 5,
#    'verse': 8}: 64, {'book': 'PSA',
#    'chapter': 119,
#    'verse': 5}: 56, {'book': 'EZE', 'chapter': 36, 'verse': 26}: 61},
#  {'book': 'PSA',
#   'chapter': 55,
#   'verse': 22}: {{'book': 'PHP',
#    'chapter': 4,
#    'verse': 6}: 149, {'book': 'MAT',
#    'chapter': 6,
#    'verse': 25}: 60, {'book': '1PE',
#    'chapter': 5,
#    'verse': 7}: 183, {'book': 'PSA',
#    'chapter': 62,
#    'verse': 6}: 53, {'book': 'PRO', 'chapter': 16, 'verse': 3}: 103},
#  {'book': 'PSA',
#   'chapter': 57,
#   'verse': 5}: {{'book': 'PSA',
#    'chapter': 108,
#    'verse': 4}: 66, {'book': 'PSA',
#    'chapter': 113,
#    'verse': 4}: 60, {'book': 'HAB',
#    'chapter': 2,
#    'verse': 14}: 126, {'book': 'ISA',
#    'chapter': 6,
#    'verse': 3}: 103, {'book': 'PSA',
#    'chapter': 72,
#    'verse': 19}: 86, {'book': 'PSA', 'chapter': 57, 'verse': 11}: 77},
#  {'book': 'NUM',
#   'chapter': 14,
#   'verse': 21}: {{'book': 'PSA', 'chapter': 57, 'verse': 5}: 84},
#  {'book': 'PSA',
#   'chapter': 82,
#   'verse': 6}: {{'book': 'JOH', 'chapter': 10, 'verse': 34}: 73},
#  {'book': 'PSA',
#   'chapter': 90,
#   'verse': 12}: {{'book': 'EPH', 'chapter': 5, 'verse': 16}: 54},
#  {'book': 'PSA',
#   'chapter': 27,
#   'verse': 5}: {{'book': 'PSA', 'chapter': 91, 'verse': 1}: 116,
#   {'book': 'ISA', 'chapter': 26, 'verse': 20}: 98},
#  {'book': 'PSA',
#   'chapter': 17,
#   'verse': 8}: {{'book': 'PSA',
#    'chapter': 91,
#    'verse': 1}: 101, {'book': 'ISA', 'chapter': 26, 'verse': 20}: 64},
#  {'book': 'PSA',
#   'chapter': 91,
#   'verse': 1}: {{'book': 'ISA', 'chapter': 32, 'verse': 2}: 64, {'book': 'ISA',
#    'chapter': 25,
#    'verse': 4}: 85, {'book': 'PSA',
#    'chapter': 121,
#    'verse': 5}: 73, {'book': '1JO', 'chapter': 4, 'verse': 15}: 84},
#  {'book': 'PSA',
#   'chapter': 31,
#   'verse': 20}: {{'book': 'PSA', 'chapter': 91, 'verse': 1}: 94},
#  {'book': 'PSA',
#   'chapter': 36,
#   'verse': 7}: {{'book': 'PSA', 'chapter': 91, 'verse': 1}: 116},
#  {'book': 'PSA',
#   'chapter': 90,
#   'verse': 1}: {{'book': 'PSA', 'chapter': 91, 'verse': 1}: 56},
#  {'book': 'PSA',
#   'chapter': 61,
#   'verse': 3}: {{'book': 'PSA', 'chapter': 91, 'verse': 1}: 76},
#  {'book': 'PSA',
#   'chapter': 32,
#   'verse': 7}: {{'book': 'PSA', 'chapter': 91, 'verse': 1}: 149,
#   {'book': 'ISA', 'chapter': 26, 'verse': 20}: 54},
#  {'book': 'PSA',
#   'chapter': 92,
#   'verse': 2}: {{'book': 'LAM', 'chapter': 3, 'verse': 22}: 82},
#  {'book': 'EXO',
#   'chapter': 15,
#   'verse': 26}: {{'book': 'PSA', 'chapter': 103, 'verse': 3}: 51},
#  {'book': 'PSA',
#   'chapter': 110,
#   'verse': 1}: {{'book': 'HEB', 'chapter': 10, 'verse': 12}: 53},
#  {'book': 'PSA',
#   'chapter': 119,
#   'verse': 5}: {{'book': '2TH', 'chapter': 3, 'verse': 5}: 51},
#  {'book': 'PSA',
#   'chapter': 119,
#   'verse': 9}: {{'book': '2TI', 'chapter': 2, 'verse': 22}: 59,
#   {'book': '2TI', 'chapter': 3, 'verse': 16}: 54},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 31}: {{'book': 'PSA', 'chapter': 119, 'verse': 11}: 52},
#  {'book': 'JOB',
#   'chapter': 29,
#   'verse': 3}: {{'book': 'PSA', 'chapter': 119, 'verse': 105}: 58},
#  {'book': 'PSA',
#   'chapter': 119,
#   'verse': 105}: {{'book': 'PRO', 'chapter': 6, 'verse': 23}: 107,
#   {'book': 'EPH', 'chapter': 5, 'verse': 13}: 56,
#   {'book': '2PE', 'chapter': 1, 'verse': 19}: 74},
#  {'book': 'PSA',
#   'chapter': 19,
#   'verse': 8}: {{'book': 'PSA', 'chapter': 119, 'verse': 105}: 57},
#  {'book': 'PSA',
#   'chapter': 18,
#   'verse': 28}: {{'book': 'PSA', 'chapter': 119, 'verse': 105}: 78},
#  {'book': 'PSA',
#   'chapter': 43,
#   'verse': 3}: {{'book': 'PSA', 'chapter': 119, 'verse': 105}: 88},
#  {'book': 'PSA',
#   'chapter': 127,
#   'verse': 1}: {{'book': 'PRO', 'chapter': 16, 'verse': 9}: 75,
#   {'book': '1CO', 'chapter': 3, 'verse': 7}: 56},
#  {'book': 'PSA',
#   'chapter': 138,
#   'verse': 8}: {{'book': 'PHP', 'chapter': 1, 'verse': 6}: 130},
#  {'book': 'PSA',
#   'chapter': 145,
#   'verse': 18}: {{'book': 'JER', 'chapter': 29, 'verse': 12}: 58,
#   {'book': 'ISA', 'chapter': 55, 'verse': 6}: 95,
#   {'book': 'JER', 'chapter': 33, 'verse': 3}: 69,
#   {'book': 'MAT', 'chapter': 7, 'verse': 7}: 69,
#   {'book': 'JAM', 'chapter': 4, 'verse': 8}: 68},
#  {'book': 'JOB',
#   'chapter': 28,
#   'verse': 28}: {{'book': 'PRO', 'chapter': 1, 'verse': 7}: 52},
#  {'book': 'PSA',
#   'chapter': 146,
#   'verse': 3}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 116,
#   {'book': 'HEB', 'chapter': 13, 'verse': 6}: 75},
#  {'book': 'PRO',
#   'chapter': 3,
#   'verse': 5}: {{'book': 'JER',
#    'chapter': 10,
#    'verse': 23}: 124, {'book': 'PRO',
#    'chapter': 22,
#    'verse': 19}: 74, {'book': 'ISA',
#    'chapter': 12,
#    'verse': 2}: 169, {'book': 'PRO',
#    'chapter': 23,
#    'verse': 4}: 63, {'book': 'ROM',
#    'chapter': 12,
#    'verse': 16}: 97, {'book': 'PRO',
#    'chapter': 28,
#    'verse': 26}: 285, {'book': '1CO',
#    'chapter': 3,
#    'verse': 18}: 119, {'book': 'JER',
#    'chapter': 9,
#    'verse': 23}: 86, {'book': 'JER',
#    'chapter': 17,
#    'verse': 7}: 378, {'book': 'ISA',
#    'chapter': 26,
#    'verse': 3}: 195, {'book': 'EPH',
#    'chapter': 1,
#    'verse': 12}: 57, {'book': 'PRO',
#    'chapter': 3,
#    'verse': 7}: 116, {'book': '1CO',
#    'chapter': 8,
#    'verse': 1}: 54, {'book': 'ISA',
#    'chapter': 30,
#    'verse': 21}: 102, {'book': 'PHP', 'chapter': 4, 'verse': 6}: 206},
#  {'book': 'PSA',
#   'chapter': 62,
#   'verse': 8}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 208, {'book': 'PHP',
#    'chapter': 4,
#    'verse': 6}: 68},
#  {'book': 'JOB',
#   'chapter': 13,
#   'verse': 15}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 64},
#  {'book': 'PSA',
#   'chapter': 125,
#   'verse': 1}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 92},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 3}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 215,
#   {'book': 'MAT', 'chapter': 6, 'verse': 33}: 90},
#  {'book': 'PSA',
#   'chapter': 115,
#   'verse': 9}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 73, {'book': 'HEB',
#    'chapter': 13,
#    'verse': 6}: 80},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 7}: {{'book': 'PRO', 'chapter': 3, 'verse': 5}: 152},
#  {'book': 'PRO',
#   'chapter': 3,
#   'verse': 6}: {{'book': 'PRO', 'chapter': 16, 'verse': 3}: 131,
#   {'book': 'JER', 'chapter': 10, 'verse': 23}: 55,
#   {'book': 'PRO', 'chapter': 16, 'verse': 9}: 68,
#   {'book': 'PHP', 'chapter': 4, 'verse': 6}: 90},
#  {'book': 'PRO',
#   'chapter': 4,
#   'verse': 23}: {{'book': 'PRO',
#    'chapter': 22,
#    'verse': 5}: 139, {'book': 'MAT', 'chapter': 15, 'verse': 19}: 291, {'book': 'PRO',
#    'chapter': 13,
#    'verse': 3}: 328, {'book': 'HEB',
#    'chapter': 12,
#    'verse': 15}: 161, {'book': 'MAR', 'chapter': 14, 'verse': 38}: 203, {'book': 'LUK',
#    'chapter': 6,
#    'verse': 45}: 704, {'book': 'MAR',
#    'chapter': 7,
#    'verse': 21}: 420, {'book': 'JER', 'chapter': 17, 'verse': 9}: 307, {'book': 'PRO',
#    'chapter': 23,
#    'verse': 19}: 241, {'book': 'JAM',
#    'chapter': 1,
#    'verse': 14}: 205, {'book': 'PRO', 'chapter': 11, 'verse': 16}: 96, {'book': 'PRO',
#    'chapter': 28,
#    'verse': 26}: 220, {'book': 'MAT',
#    'chapter': 12,
#    'verse': 34}: 511, {'book': 'ECC', 'chapter': 5, 'verse': 13}: 80},
#  {'book': 'PRO',
#   'chapter': 4,
#   'verse': 7}: {{'book': 'PRO', 'chapter': 4, 'verse': 23}: 155},
#  {'book': 'PSA',
#   'chapter': 139,
#   'verse': 23}: {{'book': 'PRO', 'chapter': 4, 'verse': 23}: 390},
#  {'book': 'PRO',
#   'chapter': 3,
#   'verse': 21}: {{'book': 'PRO', 'chapter': 4, 'verse': 23}: 145},
#  {'book': 'JOB',
#   'chapter': 22,
#   'verse': 28}: {{'book': 'PRO', 'chapter': 16, 'verse': 3}: 59},
#  {'book': 'JOB',
#   'chapter': 5,
#   'verse': 8}: {{'book': 'PRO', 'chapter': 16, 'verse': 3}: 63},
#  {'book': 'PRO',
#   'chapter': 16,
#   'verse': 3}: {{'book': 'LUK', 'chapter': 12, 'verse': 22}: 54,
#   {'book': '1PE', 'chapter': 5, 'verse': 7}: 79,
#   {'book': 'PHP', 'chapter': 4, 'verse': 6}: 72},
#  {'book': 'PRO',
#   'chapter': 16,
#   'verse': 1}: {{'book': 'PRO', 'chapter': 16, 'verse': 9}: 52},
#  {'book': 'PRO',
#   'chapter': 16,
#   'verse': 9}: {{'book': 'PRO', 'chapter': 19, 'verse': 21}: 76},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 23}: {{'book': 'PRO', 'chapter': 16, 'verse': 9}: 51},
#  {'book': 'PRO',
#   'chapter': 18,
#   'verse': 21}: {{'book': 'EPH', 'chapter': 4, 'verse': 29}: 100,
#   {'book': 'COL', 'chapter': 4, 'verse': 6}: 73,
#   {'book': 'JAM', 'chapter': 3, 'verse': 6}: 54,
#   {'book': 'MAT', 'chapter': 12, 'verse': 35}: 90},
#  {'book': 'PRO',
#   'chapter': 10,
#   'verse': 19}: {{'book': 'PRO', 'chapter': 18, 'verse': 21}: 59},
#  {'book': '2SA',
#   'chapter': 16,
#   'verse': 12}: {{'book': 'PRO', 'chapter': 20, 'verse': 22}: 56},
#  {'book': 'PRO',
#   'chapter': 17,
#   'verse': 13}: {{'book': 'PRO', 'chapter': 20, 'verse': 22}: 89},
#  {'book': 'PRO',
#   'chapter': 20,
#   'verse': 22}: {{'book': 'ROM', 'chapter': 12, 'verse': 17}: 126,
#   {'book': '1PE', 'chapter': 3, 'verse': 9}: 82,
#   {'book': '1PE', 'chapter': 4, 'verse': 19}: 58,
#   {'book': '1PE', 'chapter': 2, 'verse': 23}: 67,
#   {'book': 'MAT', 'chapter': 5, 'verse': 39}: 62,
#   {'book': 'PRO', 'chapter': 24, 'verse': 29}: 97,
#   {'book': '1TH', 'chapter': 5, 'verse': 15}: 109,
#   {'book': 'LAM', 'chapter': 3, 'verse': 25}: 56,
#   {'book': 'ISA', 'chapter': 40, 'verse': 31}: 55},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 34}: {{'book': 'PRO',
#    'chapter': 20,
#    'verse': 22}: 56, {'book': 'ISA', 'chapter': 40, 'verse': 31}: 62},
#  {'book': 'DEU',
#   'chapter': 32,
#   'verse': 35}: {{'book': 'PRO', 'chapter': 20, 'verse': 22}: 71},
#  {'book': 'PRO',
#   'chapter': 16,
#   'verse': 2}: {{'book': 'PRO', 'chapter': 21, 'verse': 2}: 51},
#  {'book': 'DEU',
#   'chapter': 6,
#   'verse': 7}: {{'book': 'PRO', 'chapter': 22, 'verse': 6}: 51},
#  {'book': 'PRO',
#   'chapter': 22,
#   'verse': 6}: {{'book': 'EPH', 'chapter': 6, 'verse': 4}: 57},
#  {'book': 'PRO',
#   'chapter': 27,
#   'verse': 17}: {{'book': 'HEB', 'chapter': 10, 'verse': 24}: 98},
#  {'book': 'PRO',
#   'chapter': 27,
#   'verse': 9}: {{'book': 'PRO', 'chapter': 27, 'verse': 17}: 60},
#  {'book': 'PRO',
#   'chapter': 28,
#   'verse': 1}: {{'book': 'ISA', 'chapter': 26, 'verse': 3}: 66},
#  {'book': 'DEU',
#   'chapter': 28,
#   'verse': 7}: {{'book': 'PRO', 'chapter': 28, 'verse': 1}: 140},
#  {'book': 'PSA',
#   'chapter': 53,
#   'verse': 5}: {{'book': 'PRO', 'chapter': 28, 'verse': 1}: 83},
#  {'book': 'PRO',
#   'chapter': 29,
#   'verse': 23}: {{'book': '1PE', 'chapter': 5, 'verse': 5}: 99,
#   {'book': 'ISA', 'chapter': 66, 'verse': 2}: 124,
#   {'book': 'LUK', 'chapter': 14, 'verse': 11}: 147,
#   {'book': 'JAM', 'chapter': 4, 'verse': 6}: 113,
#   {'book': 'MAT', 'chapter': 18, 'verse': 4}: 59,
#   {'book': 'LUK', 'chapter': 18, 'verse': 14}: 77,
#   {'book': 'MAT', 'chapter': 23, 'verse': 12}: 179,
#   {'book': 'ISA', 'chapter': 57, 'verse': 15}: 57,
#   {'book': 'ISA', 'chapter': 2, 'verse': 11}: 70,
#   {'book': 'MAT', 'chapter': 5, 'verse': 3}: 76},
#  {'book': 'PRO',
#   'chapter': 16,
#   'verse': 18}: {{'book': 'PRO', 'chapter': 29, 'verse': 23}: 86},
#  {'book': 'PRO',
#   'chapter': 18,
#   'verse': 12}: {{'book': 'PRO', 'chapter': 29, 'verse': 23}: 69},
#  {'book': 'PRO',
#   'chapter': 11,
#   'verse': 2}: {{'book': 'PRO', 'chapter': 29, 'verse': 23}: 126},
#  {'book': 'PRO',
#   'chapter': 15,
#   'verse': 33}: {{'book': 'PRO', 'chapter': 29, 'verse': 23}: 94},
#  {'book': 'DEU',
#   'chapter': 8,
#   'verse': 16}: {{'book': 'PRO', 'chapter': 29, 'verse': 23}: 51},
#  {'book': 'ECC',
#   'chapter': 11,
#   'verse': 6}: {{'book': '2CO', 'chapter': 9, 'verse': 10}: 229,
#   {'book': 'HOS', 'chapter': 10, 'verse': 12}: 93,
#   {'book': 'JOH', 'chapter': 4, 'verse': 36}: 60,
#   {'book': '1CO', 'chapter': 3, 'verse': 5}: 60,
#   {'book': 'MAR', 'chapter': 4, 'verse': 26}: 51,
#   {'book': 'HAG', 'chapter': 1, 'verse': 6}: 98,
#   {'book': 'ZEC', 'chapter': 8, 'verse': 11}: 69,
#   {'book': 'ISA', 'chapter': 55, 'verse': 10}: 175,
#   {'book': 'HAG', 'chapter': 2, 'verse': 17}: 55,
#   {'book': '2CO', 'chapter': 9, 'verse': 6}: 82},
#  {'book': 'PRO',
#   'chapter': 17,
#   'verse': 15}: {{'book': 'ISA', 'chapter': 5, 'verse': 20}: 63},
#  {'book': 'ISA',
#   'chapter': 7,
#   'verse': 14}: {{'book': 'MAT', 'chapter': 1, 'verse': 23}: 84},
#  {'book': 'ISA',
#   'chapter': 9,
#   'verse': 6}: {{'book': 'LUK', 'chapter': 2, 'verse': 11}: 80,
#   {'book': 'JER', 'chapter': 23, 'verse': 5}: 56},
#  {'book': 'ISA',
#   'chapter': 26,
#   'verse': 3}: {{'book': 'JOH',
#    'chapter': 16,
#    'verse': 33}: 106, {'book': 'JOH',
#    'chapter': 14,
#    'verse': 27}: 93, {'book': 'ROM',
#    'chapter': 5,
#    'verse': 1}: 56, {'book': 'PHP',
#    'chapter': 4,
#    'verse': 7}: 114, {'book': 'JER',
#    'chapter': 17,
#    'verse': 7}: 53, {'book': 'JOH', 'chapter': 14, 'verse': 1}: 77},
#  {'book': 'PSA',
#   'chapter': 9,
#   'verse': 10}: {{'book': 'ISA', 'chapter': 26, 'verse': 3}: 69},
#  {'book': 'ISA',
#   'chapter': 10,
#   'verse': 25}: {{'book': 'ISA', 'chapter': 26, 'verse': 20}: 56},
#  {'book': 'PSA',
#   'chapter': 91,
#   'verse': 4}: {{'book': 'ISA', 'chapter': 26, 'verse': 20}: 72},
#  {'book': 'ISA',
#   'chapter': 26,
#   'verse': 20}: {{'book': 'ISA', 'chapter': 54, 'verse': 7}: 97,
#   {'book': 'MAT', 'chapter': 6, 'verse': 6}: 80,
#   {'book': '2CO', 'chapter': 4, 'verse': 17}: 61,
#   {'book': 'ISA', 'chapter': 51, 'verse': 4}: 52},
#  {'book': 'PRO',
#   'chapter': 18,
#   'verse': 10}: {{'book': 'ISA', 'chapter': 26, 'verse': 20}: 68},
#  {'book': 'PSA',
#   'chapter': 30,
#   'verse': 5}: {{'book': 'ISA', 'chapter': 26, 'verse': 20}: 124},
#  {'book': 'ISA',
#   'chapter': 28,
#   'verse': 16}: {{'book': 'ROM', 'chapter': 9, 'verse': 33}: 51,
#   {'book': 'LUK', 'chapter': 20, 'verse': 17}: 55,
#   {'book': '1PE', 'chapter': 2, 'verse': 6}: 59,
#   {'book': 'ACT', 'chapter': 4, 'verse': 11}: 66},
#  {'book': 'PSA',
#   'chapter': 118,
#   'verse': 22}: {{'book': 'ISA', 'chapter': 28, 'verse': 16}: 81},
#  {'book': 'JOS',
#   'chapter': 1,
#   'verse': 7}: {{'book': 'ISA', 'chapter': 30, 'verse': 21}: 61},
#  {'book': 'ISA',
#   'chapter': 30,
#   'verse': 21}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 60,
#   {'book': 'ISA', 'chapter': 58, 'verse': 11}: 92,
#   {'book': 'ISA', 'chapter': 35, 'verse': 8}: 72,
#   {'book': 'ISA', 'chapter': 42, 'verse': 16}: 66,
#   {'book': 'JER', 'chapter': 6, 'verse': 16}: 62},
#  {'book': 'PSA',
#   'chapter': 143,
#   'verse': 8}: {{'book': 'ISA', 'chapter': 30, 'verse': 21}: 56},
#  {'book': 'DEU',
#   'chapter': 5,
#   'verse': 32}: {{'book': 'ISA', 'chapter': 30, 'verse': 21}: 71},
#  {'book': 'ISA',
#   'chapter': 40,
#   'verse': 3}: {{'book': 'MAR', 'chapter': 1, 'verse': 2}: 59,
#   {'book': 'JOH', 'chapter': 1, 'verse': 23}: 52,
#   {'book': 'MAL', 'chapter': 3, 'verse': 1}: 66},
#  {'book': 'ISA',
#   'chapter': 40,
#   'verse': 31}: {{'book': 'LAM',
#    'chapter': 3,
#    'verse': 25}: 175, {'book': '2CO',
#    'chapter': 12,
#    'verse': 9}: 120, {'book': '2CO',
#    'chapter': 4,
#    'verse': 16}: 189, {'book': 'ROM',
#    'chapter': 8,
#    'verse': 25}: 74, {'book': 'HEB',
#    'chapter': 12,
#    'verse': 1}: 102, {'book': 'GAL',
#    'chapter': 6,
#    'verse': 9}: 84, {'book': '2CO',
#    'chapter': 4,
#    'verse': 8}: 68, {'book': 'LUK',
#    'chapter': 18,
#    'verse': 1}: 65, {'book': 'EPH', 'chapter': 6, 'verse': 10}: 78},
#  {'book': 'PSA',
#   'chapter': 27,
#   'verse': 13}: {{'book': 'ISA',
#    'chapter': 40,
#    'verse': 31}: 131, {'book': '1PE', 'chapter': 5, 'verse': 7}: 57},
#  {'book': 'EXO',
#   'chapter': 19,
#   'verse': 4}: {{'book': 'ISA', 'chapter': 40, 'verse': 31}: 51},
#  {'book': 'PSA',
#   'chapter': 84,
#   'verse': 7}: {{'book': 'ISA', 'chapter': 40, 'verse': 31}: 69},
#  {'book': 'PSA',
#   'chapter': 103,
#   'verse': 5}: {{'book': 'ISA', 'chapter': 40, 'verse': 31}: 140},
#  {'book': 'ISA',
#   'chapter': 25,
#   'verse': 9}: {{'book': 'ISA', 'chapter': 40, 'verse': 31}: 58},
#  {'book': 'PSA',
#   'chapter': 138,
#   'verse': 3}: {{'book': 'ISA', 'chapter': 40, 'verse': 31}: 53},
#  {'book': 'ISA',
#   'chapter': 30,
#   'verse': 18}: {{'book': 'ISA', 'chapter': 40, 'verse': 31}: 73},
#  {'book': 'ISA',
#   'chapter': 41,
#   'verse': 10}: {{'book': 'ZEC', 'chapter': 13, 'verse': 9}: 154,
#   {'book': 'ROM', 'chapter': 8, 'verse': 31}: 392,
#   {'book': 'ISA', 'chapter': 44, 'verse': 2}: 68,
#   {'book': 'ISA', 'chapter': 41, 'verse': 13}: 249,
#   {'book': '2CO', 'chapter': 12, 'verse': 9}: 246,
#   {'book': 'ISA', 'chapter': 43, 'verse': 1}: 444,
#   {'book': 'EPH', 'chapter': 3, 'verse': 16}: 125,
#   {'book': 'ISA', 'chapter': 60, 'verse': 19}: 188,
#   {'book': 'PHP', 'chapter': 4, 'verse': 13}: 683,
#   {'book': 'ISA', 'chapter': 52, 'verse': 7}: 88,
#   {'book': 'LUK', 'chapter': 1, 'verse': 13}: 73,
#   {'book': 'ISA', 'chapter': 49, 'verse': 8}: 107,
#   {'book': 'LUK', 'chapter': 1, 'verse': 30}: 80,
#   {'book': 'ZEC', 'chapter': 10, 'verse': 12}: 116,
#   {'book': 'ISA', 'chapter': 51, 'verse': 12}: 147,
#   {'book': 'JOH', 'chapter': 8, 'verse': 54}: 84,
#   {'book': 'LUK', 'chapter': 2, 'verse': 10}: 80,
#   {'book': 'ISA', 'chapter': 43, 'verse': 5}: 116,
#   {'book': 'ISA', 'chapter': 43, 'verse': 2}: 60,
#   {'book': 'JOH', 'chapter': 14, 'verse': 27}: 67,
#   {'book': 'HEB', 'chapter': 13, 'verse': 6}: 241},
#  {'book': 'PSA',
#   'chapter': 99,
#   'verse': 4}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 69},
#  {'book': 'DEU',
#   'chapter': 33,
#   'verse': 27}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 104},
#  {'book': 'GEN',
#   'chapter': 15,
#   'verse': 1}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 87,
#   {'book': 'ROM', 'chapter': 8, 'verse': 31}: 53,
#   {'book': 'HEB', 'chapter': 13, 'verse': 6}: 93},
#  {'book': 'PSA',
#   'chapter': 144,
#   'verse': 11}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 96},
#  {'book': 'PSA',
#   'chapter': 46,
#   'verse': 11}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 106},
#  {'book': 'ISA',
#   'chapter': 40,
#   'verse': 29}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 309,
#   {'book': '2CO', 'chapter': 12, 'verse': 9}: 90,
#   {'book': 'PHP', 'chapter': 4, 'verse': 13}: 391},
#  {'book': 'ISA',
#   'chapter': 12,
#   'verse': 2}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 181},
#  {'book': '1CH',
#   'chapter': 12,
#   'verse': 18}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 71},
#  {'book': 'PSA',
#   'chapter': 147,
#   'verse': 12}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 84},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 17}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 102},
#  {'book': 'PSA',
#   'chapter': 63,
#   'verse': 8}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 212},
#  {'book': '2CH',
#   'chapter': 32,
#   'verse': 8}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 129},
#  {'book': '2CH',
#   'chapter': 20,
#   'verse': 17}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 194},
#  {'book': 'PSA',
#   'chapter': 37,
#   'verse': 24}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 135},
#  {'book': 'PSA',
#   'chapter': 41,
#   'verse': 12}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 88},
#  {'book': 'PSA',
#   'chapter': 29,
#   'verse': 11}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 133},
#  {'book': 'PSA',
#   'chapter': 145,
#   'verse': 14}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 174},
#  {'book': 'PSA',
#   'chapter': 46,
#   'verse': 7}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 88},
#  {'book': 'PSA',
#   'chapter': 65,
#   'verse': 5}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 82},
#  {'book': 'PSA',
#   'chapter': 89,
#   'verse': 13}: {{'book': 'ISA', 'chapter': 41, 'verse': 10}: 132},
#  {'book': 'PSA',
#   'chapter': 66,
#   'verse': 12}: {{'book': 'ISA', 'chapter': 43, 'verse': 2}: 57},
#  {'book': 'ISA',
#   'chapter': 43,
#   'verse': 19}: {{'book': 'REV', 'chapter': 21, 'verse': 5}: 64,
#   {'book': 'ISA', 'chapter': 48, 'verse': 6}: 104,
#   {'book': '2CO', 'chapter': 5, 'verse': 17}: 79,
#   {'book': 'ISA', 'chapter': 44, 'verse': 3}: 199},
#  {'book': 'ISA',
#   'chapter': 41,
#   'verse': 18}: {{'book': 'ISA', 'chapter': 43, 'verse': 19}: 65},
#  {'book': 'ISA',
#   'chapter': 42,
#   'verse': 9}: {{'book': 'ISA', 'chapter': 43, 'verse': 19}: 83},
#  {'book': 'ISA',
#   'chapter': 37,
#   'verse': 35}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 51},
#  {'book': 'ISA',
#   'chapter': 43,
#   'verse': 11}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 95},
#  {'book': 'ISA',
#   'chapter': 43,
#   'verse': 25}: {{'book': 'MIC', 'chapter': 7, 'verse': 18}: 316,
#   {'book': 'HEB', 'chapter': 10, 'verse': 17}: 268,
#   {'book': 'ACT', 'chapter': 3, 'verse': 19}: 131,
#   {'book': 'JER', 'chapter': 50, 'verse': 20}: 81,
#   {'book': 'ISA', 'chapter': 48, 'verse': 8}: 76,
#   {'book': 'HEB', 'chapter': 8, 'verse': 12}: 335,
#   {'book': 'EZE', 'chapter': 20, 'verse': 9}: 58,
#   {'book': 'MAR', 'chapter': 2, 'verse': 7}: 101,
#   {'book': 'JER', 'chapter': 31, 'verse': 34}: 261,
#   {'book': 'EZE', 'chapter': 36, 'verse': 22}: 69,
#   {'book': 'ROM', 'chapter': 5, 'verse': 20}: 115,
#   {'book': 'EZE', 'chapter': 20, 'verse': 14}: 58,
#   {'book': 'ISA', 'chapter': 44, 'verse': 22}: 229},
#  {'book': 'PSA',
#   'chapter': 79,
#   'verse': 8}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 156},
#  {'book': 'ISA',
#   'chapter': 1,
#   'verse': 18}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 231},
#  {'book': 'ISA',
#   'chapter': 38,
#   'verse': 17}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 139},
#  {'book': 'PSA',
#   'chapter': 25,
#   'verse': 7}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 174},
#  {'book': 'PSA',
#   'chapter': 51,
#   'verse': 9}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 93},
#  {'book': 'PSA',
#   'chapter': 25,
#   'verse': 11}: {{'book': 'ISA', 'chapter': 43, 'verse': 25}: 94},
#  {'book': 'PSA',
#   'chapter': 71,
#   'verse': 6}: {{'book': 'ISA', 'chapter': 44, 'verse': 2}: 54},
#  {'book': 'ISA',
#   'chapter': 44,
#   'verse': 2}: {{'book': 'ROM', 'chapter': 8, 'verse': 30}: 60,
#   {'book': 'EZE', 'chapter': 16, 'verse': 4}: 66,
#   {'book': 'ISA', 'chapter': 49, 'verse': 1}: 74,
#   {'book': 'JER', 'chapter': 1, 'verse': 5}: 181,
#   {'book': 'ISA', 'chapter': 44, 'verse': 24}: 82,
#   {'book': 'ISA', 'chapter': 46, 'verse': 3}: 94,
#   {'book': 'EPH', 'chapter': 1, 'verse': 4}: 70},
#  {'book': 'ISA',
#   'chapter': 43,
#   'verse': 1}: {{'book': 'ISA', 'chapter': 44, 'verse': 2}: 123},
#  {'book': 'ISA',
#   'chapter': 43,
#   'verse': 7}: {{'book': 'ISA', 'chapter': 44, 'verse': 2}: 85},
#  {'book': 'ISA',
#   'chapter': 44,
#   'verse': 3}: {{'book': 'EZE', 'chapter': 39, 'verse': 29}: 273,
#   {'book': 'REV', 'chapter': 21, 'verse': 6}: 352,
#   {'book': 'JOE', 'chapter': 2, 'verse': 28}: 919,
#   {'book': 'ISA', 'chapter': 49, 'verse': 10}: 141,
#   {'book': 'EZE', 'chapter': 34, 'verse': 26}: 168,
#   {'book': 'ACT', 'chapter': 2, 'verse': 39}: 284,
#   {'book': 'ZEC', 'chapter': 12, 'verse': 10}: 291,
#   {'book': 'TIT', 'chapter': 3, 'verse': 5}: 214,
#   {'book': 'ACT', 'chapter': 2, 'verse': 17}: 829,
#   {'book': 'ISA', 'chapter': 61, 'verse': 9}: 155,
#   {'book': 'ACT', 'chapter': 10, 'verse': 45}: 222,
#   {'book': 'MAT', 'chapter': 12, 'verse': 43}: 132,
#   {'book': 'ISA', 'chapter': 59, 'verse': 21}: 84,
#   {'book': 'JOE', 'chapter': 3, 'verse': 18}: 187,
#   {'book': 'ACT', 'chapter': 2, 'verse': 33}: 176,
#   {'book': 'REV', 'chapter': 22, 'verse': 17}: 150,
#   {'book': 'JOH', 'chapter': 7, 'verse': 37}: 433,
#   {'book': 'ISA', 'chapter': 65, 'verse': 23}: 148,
#   {'book': 'ISA', 'chapter': 48, 'verse': 21}: 150,
#   {'book': 'JOH', 'chapter': 7, 'verse': 38}: 96},
#  {'book': 'PRO',
#   'chapter': 1,
#   'verse': 23}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 396},
#  {'book': 'PSA',
#   'chapter': 78,
#   'verse': 15}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 152},
#  {'book': 'ISA',
#   'chapter': 32,
#   'verse': 2}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 137},
#  {'book': 'ISA',
#   'chapter': 41,
#   'verse': 17}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 187},
#  {'book': 'ISA',
#   'chapter': 32,
#   'verse': 15}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 238},
#  {'book': 'PSA',
#   'chapter': 107,
#   'verse': 35}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 204},
#  {'book': 'ISA',
#   'chapter': 35,
#   'verse': 6}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 162},
#  {'book': 'PSA',
#   'chapter': 63,
#   'verse': 1}: {{'book': 'ISA', 'chapter': 44, 'verse': 3}: 143},
#  {'book': 'ISA',
#   'chapter': 43,
#   'verse': 10}: {{'book': 'ISA', 'chapter': 44, 'verse': 6}: 55},
#  {'book': 'ISA',
#   'chapter': 44,
#   'verse': 6}: {{'book': 'REV', 'chapter': 1, 'verse': 8}: 53},
#  {'book': 'ISA',
#   'chapter': 41,
#   'verse': 4}: {{'book': 'ISA', 'chapter': 44, 'verse': 6}: 61},
#  {'book': 'ISA',
#   'chapter': 44,
#   'verse': 18}: {{'book': 'JOH', 'chapter': 12, 'verse': 39}: 106,
#   {'book': 'MAT', 'chapter': 13, 'verse': 14}: 56,
#   {'book': 'JOH', 'chapter': 5, 'verse': 44}: 53,
#   {'book': 'JER', 'chapter': 5, 'verse': 21}: 80,
#   {'book': '2TH', 'chapter': 2, 'verse': 9}: 99,
#   {'book': 'JOH', 'chapter': 8, 'verse': 43}: 52,
#   {'book': '2CO', 'chapter': 4, 'verse': 3}: 140,
#   {'book': 'ROM', 'chapter': 1, 'verse': 21}: 53,
#   {'book': 'MAR', 'chapter': 8, 'verse': 18}: 81},
#  {'book': 'PRO',
#   'chapter': 2,
#   'verse': 5}: {{'book': 'ISA', 'chapter': 44, 'verse': 18}: 58},
#  {'book': 'PSA',
#   'chapter': 81,
#   'verse': 12}: {{'book': 'ISA', 'chapter': 44, 'verse': 18}: 64},
#  {'book': 'ISA',
#   'chapter': 6,
#   'verse': 9}: {{'book': 'ISA', 'chapter': 44, 'verse': 18}: 129,
#   {'book': 'MAR', 'chapter': 8, 'verse': 18}: 110},
#  {'book': 'ISA',
#   'chapter': 45,
#   'verse': 17}: {{'book': '1JO',
#    'chapter': 4,
#    'verse': 15}: 66, {'book': 'JOH',
#    'chapter': 10,
#    'verse': 28}: 51, {'book': 'ISA',
#    'chapter': 54,
#    'verse': 4}: 193, {'book': 'HEB',
#    'chapter': 5,
#    'verse': 9}: 54, {'book': 'JOH',
#    'chapter': 5,
#    'verse': 24}: 62, {'book': 'JOE',
#    'chapter': 2,
#    'verse': 26}: 168, {'book': 'ROM',
#    'chapter': 11,
#    'verse': 26}: 51, {'book': '1PE',
#    'chapter': 2,
#    'verse': 6}: 183, {'book': '2TH',
#    'chapter': 2,
#    'verse': 16}: 52, {'book': 'ISA',
#    'chapter': 49,
#    'verse': 23}: 159, {'book': 'ROM',
#    'chapter': 10,
#    'verse': 11}: 273, {'book': 'ISA',
#    'chapter': 60,
#    'verse': 19}: 51, {'book': 'JER',
#    'chapter': 31,
#    'verse': 3}: 67, {'book': 'ROM',
#    'chapter': 9,
#    'verse': 33}: 144, {'book': 'ROM', 'chapter': 8, 'verse': 1}: 57},
#  {'book': 'PSA',
#   'chapter': 103,
#   'verse': 17}: {{'book': 'ISA', 'chapter': 45, 'verse': 17}: 73},
#  {'book': 'ISA',
#   'chapter': 26,
#   'verse': 4}: {{'book': 'ISA', 'chapter': 45, 'verse': 17}: 105},
#  {'book': 'PSA',
#   'chapter': 25,
#   'verse': 12}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 138},
#  {'book': 'ISA',
#   'chapter': 48,
#   'verse': 17}: {{'book': 'JOH', 'chapter': 6, 'verse': 45}: 55,
#   {'book': 'ISA', 'chapter': 54, 'verse': 13}: 67},
#  {'book': 'JOB',
#   'chapter': 22,
#   'verse': 21}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 112},
#  {'book': 'ISA',
#   'chapter': 30,
#   'verse': 20}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 78},
#  {'book': 'DEU',
#   'chapter': 8,
#   'verse': 17}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 107},
#  {'book': 'PSA',
#   'chapter': 73,
#   'verse': 24}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 68},
#  {'book': 'JOB',
#   'chapter': 36,
#   'verse': 22}: {{'book': 'ISA', 'chapter': 48, 'verse': 17}: 68},
#  {'book': 'ISA',
#   'chapter': 53,
#   'verse': 5}: {{'book': '1PE', 'chapter': 2, 'verse': 24}: 120},
#  {'book': 'ISA',
#   'chapter': 54,
#   'verse': 17}: {{'book': 'JOH', 'chapter': 10, 'verse': 28}: 67,
#   {'book': 'ROM', 'chapter': 8, 'verse': 28}: 88,
#   {'book': 'ROM', 'chapter': 8, 'verse': 31}: 102},
#  {'book': 'ISA',
#   'chapter': 54,
#   'verse': 15}: {{'book': 'ISA', 'chapter': 54, 'verse': 17}: 59},
#  {'book': 'PSA',
#   'chapter': 32,
#   'verse': 6}: {{'book': 'ISA', 'chapter': 55, 'verse': 6}: 68},
#  {'book': 'ISA',
#   'chapter': 45,
#   'verse': 19}: {{'book': 'ISA', 'chapter': 55, 'verse': 6}: 79},
#  {'book': 'ISA',
#   'chapter': 55,
#   'verse': 6}: {{'book': 'ISA', 'chapter': 65, 'verse': 24}: 56,
#   {'book': 'JER', 'chapter': 29, 'verse': 12}: 143,
#   {'book': 'JER', 'chapter': 33, 'verse': 3}: 62,
#   {'book': 'LUK', 'chapter': 11, 'verse': 9}: 56},
#  {'book': 'PSA',
#   'chapter': 14,
#   'verse': 2}: {{'book': 'ISA', 'chapter': 55, 'verse': 6}: 62},
#  {'book': 'ISA',
#   'chapter': 55,
#   'verse': 11}: {{'book': 'MAT', 'chapter': 24, 'verse': 35}: 191,
#   {'book': 'ROM', 'chapter': 10, 'verse': 17}: 55,
#   {'book': 'JOH', 'chapter': 6, 'verse': 63}: 52,
# ...
#   'verse': 14}: {{'book': '1TH', 'chapter': 5, 'verse': 6}: 53},
#  {'book': 'EPH',
#   'chapter': 6,
#   'verse': 10}: {{'book': 'PHP', 'chapter': 4, 'verse': 13}: 430},
#  {'book': '2CO',
#   'chapter': 10,
#   'verse': 4}: {{'book': 'EPH', 'chapter': 6, 'verse': 11}: 56},
#  {'book': 'EPH',
#   'chapter': 2,
#   'verse': 2}: {{'book': 'EPH', 'chapter': 6, 'verse': 12}: 54},
#  {'book': 'EPH',
#   'chapter': 6,
#   'verse': 12}: {{'book': 'COL', 'chapter': 1, 'verse': 13}: 74},
#  {'book': '2CO',
#   'chapter': 4,
#   'verse': 4}: {{'book': 'EPH', 'chapter': 6, 'verse': 12}: 62},
#  {'book': '1CO',
#   'chapter': 1,
#   'verse': 8}: {{'book': 'PHP', 'chapter': 1, 'verse': 6}: 107},
#  {'book': 'PHP',
#   'chapter': 1,
#   'verse': 6}: {{'book': '1PE', 'chapter': 5, 'verse': 10}: 140,
#   {'book': '2TH', 'chapter': 1, 'verse': 11}: 75,
#   {'book': 'HEB', 'chapter': 13, 'verse': 20}: 191,
#   {'book': 'PHP', 'chapter': 2, 'verse': 13}: 273,
#   {'book': '1TH', 'chapter': 5, 'verse': 23}: 272,
#   {'book': 'HEB', 'chapter': 10, 'verse': 35}: 54},
#  {'book': 'EPH',
#   'chapter': 4,
#   'verse': 12}: {{'book': 'PHP', 'chapter': 1, 'verse': 6}: 211},
#  {'book': 'ROM',
#   'chapter': 12,
#   'verse': 10}: {{'book': 'PHP', 'chapter': 2, 'verse': 3}: 63},
#  {'book': '1CO',
#   'chapter': 10,
#   'verse': 24}: {{'book': 'PHP', 'chapter': 2, 'verse': 4}: 55},
#  {'book': 'PHP',
#   'chapter': 2,
#   'verse': 13}: {{'book': 'HEB', 'chapter': 13, 'verse': 21}: 88},
#  {'book': 'LUK',
#   'chapter': 9,
#   'verse': 62}: {{'book': 'PHP', 'chapter': 3, 'verse': 13}: 56},
#  {'book': '1CO',
#   'chapter': 9,
#   'verse': 24}: {{'book': 'PHP', 'chapter': 3, 'verse': 14}: 59,
#   {'book': 'HEB', 'chapter': 12, 'verse': 1}: 82},
#  {'book': 'PHP',
#   'chapter': 4,
#   'verse': 6}: {{'book': 'COL', 'chapter': 4, 'verse': 2}: 52, {'book': '1TH',
#    'chapter': 5,
#    'verse': 17}: 115, {'book': '1PE',
#    'chapter': 5,
#    'verse': 7}: 143, {'book': 'COL', 'chapter': 3, 'verse': 17}: 61, {'book': '1TH',
#    'chapter': 5,
#    'verse': 18}: 64},
#  {'book': 'PSA',
#   'chapter': 34,
#   'verse': 5}: {{'book': 'PHP', 'chapter': 4, 'verse': 6}: 109},
#  {'book': 'EPH',
#   'chapter': 6,
#   'verse': 18}: {{'book': 'PHP', 'chapter': 4, 'verse': 6}: 64,
#   {'book': '1TH', 'chapter': 5, 'verse': 17}: 53},
#  {'book': 'MAT',
#   'chapter': 6,
#   'verse': 8}: {{'book': 'PHP', 'chapter': 4, 'verse': 6}: 87},
#  {'book': 'ROM',
#   'chapter': 12,
#   'verse': 9}: {{'book': 'PHP', 'chapter': 4, 'verse': 8}: 56},
#  {'book': 'PHP',
#   'chapter': 4,
#   'verse': 8}: {{'book': 'TIT', 'chapter': 2, 'verse': 7}: 66,
#   {'book': 'JAM', 'chapter': 3, 'verse': 17}: 98},
#  {'book': 'ISA',
#   'chapter': 45,
#   'verse': 24}: {{'book': 'PHP', 'chapter': 4, 'verse': 13}: 205},
#  {'book': 'PHP',
#   'chapter': 4,
#   'verse': 13}: {{'book': 'COL', 'chapter': 1, 'verse': 11}: 452},
#  {'book': '2CO',
#   'chapter': 3,
#   'verse': 4}: {{'book': 'PHP', 'chapter': 4, 'verse': 13}: 310},
#  {'book': 'JOH',
#   'chapter': 15,
#   'verse': 4}: {{'book': 'PHP', 'chapter': 4, 'verse': 13}: 280},
#  {'book': 'EPH',
#   'chapter': 3,
#   'verse': 16}: {{'book': 'PHP', 'chapter': 4, 'verse': 13}: 351},
#  {'book': 'PHP',
#   'chapter': 4,
#   'verse': 19}: {{'book': '1TI', 'chapter': 6, 'verse': 17}: 64,
#   {'book': '1PE', 'chapter': 5, 'verse': 10}: 61},
#  {'book': 'ROM',
#   'chapter': 8,
#   'verse': 6}: {{'book': 'COL', 'chapter': 3, 'verse': 1}: 70},
#  {'book': 'COL',
#   'chapter': 3,
#   'verse': 2}: {{'book': '1JO', 'chapter': 2, 'verse': 15}: 62},
#  {'book': 'EPH',
#   'chapter': 4,
#   'verse': 32}: {{'book': 'COL', 'chapter': 3, 'verse': 12}: 51},
#  {'book': 'COL',
#   'chapter': 3,
#   'verse': 17}: {{'book': 'COL', 'chapter': 3, 'verse': 23}: 115,
#   {'book': '1TH', 'chapter': 5, 'verse': 18}: 51},
#  {'book': 'EPH',
#   'chapter': 6,
#   'verse': 6}: {{'book': 'COL', 'chapter': 3, 'verse': 23}: 85},
#  {'book': 'ROM',
#   'chapter': 14,
#   'verse': 8}: {{'book': 'COL', 'chapter': 3, 'verse': 23}: 54},
#  {'book': 'ECC',
#   'chapter': 9,
#   'verse': 10}: {{'book': 'COL', 'chapter': 3, 'verse': 23}: 51},
#  {'book': 'COL',
#   'chapter': 4,
#   'verse': 2}: {{'book': '1TH', 'chapter': 5, 'verse': 17}: 71},
#  {'book': 'ROM',
#   'chapter': 12,
#   'verse': 12}: {{'book': '1TH', 'chapter': 5, 'verse': 17}: 77},
#  {'book': 'EPH',
#   'chapter': 5,
#   'verse': 20}: {{'book': '1TH', 'chapter': 5, 'verse': 18}: 85},
#  {'book': '1TI',
#   'chapter': 4,
#   'verse': 12}: {{'book': 'TIT', 'chapter': 2, 'verse': 7}: 72},
#  {'book': 'PRO',
#   'chapter': 2,
#   'verse': 7}: {{'book': '2TI', 'chapter': 1, 'verse': 7}: 65},
#  {'book': 'PRO',
#   'chapter': 8,
#   'verse': 14}: {{'book': '2TI', 'chapter': 1, 'verse': 7}: 52},
#  {'book': '2TI',
#   'chapter': 1,
#   'verse': 7}: {{'book': '1JO', 'chapter': 4, 'verse': 18}: 83,
#   {'book': 'HEB', 'chapter': 2, 'verse': 15}: 51},
#  {'book': 'ROM',
#   'chapter': 8,
#   'verse': 15}: {{'book': '2TI',
#    'chapter': 1,
#    'verse': 7}: 162, {'book': '1JO', 'chapter': 4, 'verse': 18}: 61},
#  {'book': '1TH',
#   'chapter': 2,
#   'verse': 4}: {{'book': '2TI', 'chapter': 2, 'verse': 15}: 54},
#  {'book': 'NUM',
#   'chapter': 16,
#   'verse': 5}: {{'book': '2TI', 'chapter': 2, 'verse': 19}: 58},
#  {'book': 'JOH',
#   'chapter': 10,
#   'verse': 14}: {{'book': '2TI', 'chapter': 2, 'verse': 19}: 108},
#  {'book': '2TI',
#   'chapter': 2,
#   'verse': 19}: {{'book': '1JO', 'chapter': 3, 'verse': 7}: 67},
#  {'book': 'LUK',
#   'chapter': 13,
#   'verse': 27}: {{'book': '2TI', 'chapter': 2, 'verse': 19}: 51},
#  {'book': 'PRO',
#   'chapter': 6,
#   'verse': 23}: {{'book': '2TI', 'chapter': 3, 'verse': 16}: 52},
#  {'book': 'MAR',
#   'chapter': 12,
#   'verse': 24}: {{'book': '2TI', 'chapter': 3, 'verse': 16}: 71},
#  {'book': 'ROM',
#   'chapter': 15,
#   'verse': 4}: {{'book': '2TI', 'chapter': 3, 'verse': 16}: 159},
#  {'book': '2TI',
#   'chapter': 3,
#   'verse': 16}: {{'book': '2PE', 'chapter': 1, 'verse': 19}: 88,
#   {'book': 'HEB', 'chapter': 4, 'verse': 12}: 123},
#  {'book': 'PSA',
#   'chapter': 95,
#   'verse': 7}: {{'book': 'HEB', 'chapter': 3, 'verse': 7}: 121},
#  {'book': 'HEB',
#   'chapter': 3,
#   'verse': 7}: {{'book': 'HEB', 'chapter': 4, 'verse': 7}: 58,
#   {'book': 'REV', 'chapter': 3, 'verse': 20}: 63,
#   {'book': 'HEB', 'chapter': 3, 'verse': 15}: 83},
#  {'book': 'EPH',
#   'chapter': 6,
#   'verse': 17}: {{'book': 'HEB', 'chapter': 4, 'verse': 12}: 70},
#  {'book': 'PSA',
#   'chapter': 119,
#   'verse': 130}: {{'book': 'HEB', 'chapter': 4, 'verse': 12}: 57},
#  {'book': 'JER',
#   'chapter': 23,
#   'verse': 29}: {{'book': 'HEB', 'chapter': 4, 'verse': 12}: 121},
#  {'book': 'ISA',
#   'chapter': 49,
#   'verse': 2}: {{'book': 'HEB', 'chapter': 4, 'verse': 12}: 53},
#  {'book': 'EPH',
#   'chapter': 3,
#   'verse': 12}: {{'book': 'HEB', 'chapter': 4, 'verse': 16}: 58,
#   {'book': 'HEB', 'chapter': 13, 'verse': 6}: 88},
#  {'book': 'TIT',
#   'chapter': 2,
#   'verse': 14}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 61},
#  {'book': 'ROM',
#   'chapter': 9,
#   'verse': 25}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 68},
#  {'book': 'HEB',
#   'chapter': 8,
#   'verse': 10}: {{'book': 'HEB', 'chapter': 10, 'verse': 16}: 117,
#   {'book': '1PE', 'chapter': 1, 'verse': 23}: 52,
#   {'book': '1PE', 'chapter': 2, 'verse': 9}: 80,
#   {'book': 'JAM', 'chapter': 1, 'verse': 21}: 59,
#   {'book': 'JAM', 'chapter': 1, 'verse': 18}: 52},
#  {'book': '2CO',
#   'chapter': 3,
#   'verse': 7}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 58},
#  {'book': 'DEU',
#   'chapter': 30,
#   'verse': 6}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 110},
#  {'book': '2CO',
#   'chapter': 3,
#   'verse': 3}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 144},
#  {'book': 'ROM',
#   'chapter': 11,
#   'verse': 27}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 63},
#  {'book': 'EZE',
#   'chapter': 37,
#   'verse': 27}: {{'book': 'HEB', 'chapter': 8, 'verse': 10}: 55},
#  {'book': 'MAT',
#   'chapter': 18,
#   'verse': 20}: {{'book': 'HEB', 'chapter': 10, 'verse': 25}: 52},
#  {'book': 'ACT',
#   'chapter': 2,
#   'verse': 42}: {{'book': 'HEB', 'chapter': 10, 'verse': 25}: 63},
#  {'book': 'HEB',
#   'chapter': 11,
#   'verse': 1}: {{'book': 'HEB', 'chapter': 11, 'verse': 7}: 65},
#  {'book': 'HEB',
#   'chapter': 10,
#   'verse': 22}: {{'book': 'HEB', 'chapter': 11, 'verse': 1}: 54},
#  {'book': 'ROM',
#   'chapter': 8,
#   'verse': 24}: {{'book': 'HEB', 'chapter': 11, 'verse': 1}: 87},
#  {'book': 'JER',
#   'chapter': 29,
#   'verse': 13}: {{'book': 'HEB', 'chapter': 11, 'verse': 6}: 80},
#  {'book': 'PRO',
#   'chapter': 8,
#   'verse': 17}: {{'book': 'HEB', 'chapter': 11, 'verse': 6}: 76},
#  {'book': '2TI',
#   'chapter': 4,
#   'verse': 7}: {{'book': 'HEB', 'chapter': 12, 'verse': 1}: 93},
#  {'book': 'LUK',
#   'chapter': 21,
#   'verse': 34}: {{'book': 'HEB', 'chapter': 12, 'verse': 1}: 56},
#  {'book': 'PHP',
#   'chapter': 2,
#   'verse': 16}: {{'book': 'HEB', 'chapter': 12, 'verse': 1}: 63},
#  {'book': 'JOS',
#   'chapter': 1,
#   'verse': 5}: {{'book': 'HEB', 'chapter': 13, 'verse': 5}: 76},
#  {'book': 'DEU',
#   'chapter': 31,
#   'verse': 8}: {{'book': 'HEB', 'chapter': 13, 'verse': 5}: 88},
#  {'book': 'DEU',
#   'chapter': 33,
#   'verse': 26}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 77},
#  {'book': 'PSA',
#   'chapter': 94,
#   'verse': 17}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 101},
#  {'book': 'PSA',
#   'chapter': 63,
#   'verse': 7}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 115},
#  {'book': 'PSA',
#   'chapter': 54,
#   'verse': 4}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 120},
#  {'book': 'PSA',
#   'chapter': 27,
#   'verse': 9}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 84},
#  {'book': 'ISA',
#   'chapter': 41,
#   'verse': 14}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 83},
#  {'book': 'MAT',
#   'chapter': 10,
#   'verse': 28}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 123},
#  {'book': 'DAN',
#   'chapter': 3,
#   'verse': 16}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 103},
#  {'book': 'EXO',
#   'chapter': 18,
#   'verse': 4}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 75},
#  {'book': 'HEB',
#   'chapter': 4,
#   'verse': 16}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 154},
#  {'book': 'LUK',
#   'chapter': 12,
#   'verse': 4}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 101},
#  {'book': 'PSA',
#   'chapter': 124,
#   'verse': 8}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 159},
#  {'book': 'HEB',
#   'chapter': 10,
#   'verse': 19}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 68},
#  {'book': 'PSA',
#   'chapter': 40,
#   'verse': 17}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 100},
#  {'book': 'PSA',
#   'chapter': 18,
#   'verse': 1}: {{'book': 'HEB', 'chapter': 13, 'verse': 6}: 66},
#  {'book': 'HEB',
#   'chapter': 13,
#   'verse': 8}: {{'book': 'JAM', 'chapter': 1, 'verse': 17}: 56},
#  {'book': 'JAM',
#   'chapter': 1,
#   'verse': 2}: {{'book': 'JAM', 'chapter': 1, 'verse': 12}: 71,
#   {'book': '1PE', 'chapter': 1, 'verse': 6}: 88},
#  {'book': 'PRO',
#   'chapter': 2,
#   'verse': 3}: {{'book': 'JAM', 'chapter': 1, 'verse': 5}: 62},
#  {'book': 'JAM',
#   'chapter': 1,
#   'verse': 12}: {{'book': '1PE', 'chapter': 5, 'verse': 10}: 68},
#  {'book': 'JOH',
#   'chapter': 3,
#   'verse': 27}: {{'book': 'JAM', 'chapter': 1, 'verse': 17}: 57},
#  {'book': 'PRO',
#   'chapter': 17,
#   'verse': 27}: {{'book': 'JAM', 'chapter': 1, 'verse': 19}: 66},
#  {'book': 'PRO',
#   'chapter': 21,
#   'verse': 23}: {{'book': 'JAM', 'chapter': 1, 'verse': 19}: 51},
#  {'book': 'ROM',
#   'chapter': 2,
#   'verse': 13}: {{'book': 'JAM', 'chapter': 1, 'verse': 22}: 72},
#  {'book': 'LUK',
#   'chapter': 6,
#   'verse': 46}: {{'book': 'JAM', 'chapter': 1, 'verse': 22}: 53},
#  {'book': 'EPH',
#   'chapter': 4,
#   'verse': 27}: {{'book': 'JAM', 'chapter': 4, 'verse': 7}: 58,
#   {'book': '1PE', 'chapter': 5, 'verse': 8}: 74},
#  {'book': 'EPH',
#   'chapter': 6,
#   'verse': 11}: {{'book': 'JAM', 'chapter': 4, 'verse': 7}: 51, {'book': '1PE',
#    'chapter': 5,
#    'verse': 8}: 108},
#  {'book': 'JAM',
#   'chapter': 4,
#   'verse': 7}: {{'book': '1PE', 'chapter': 5, 'verse': 8}: 90},
#  {'book': 'MAL',
#   'chapter': 3,
#   'verse': 7}: {{'book': 'JAM', 'chapter': 4, 'verse': 8}: 54},
#  {'book': 'LEV',
#   'chapter': 11,
#   'verse': 44}: {{'book': '1PE', 'chapter': 1, 'verse': 16}: 56},
#  {'book': '1PE',
#   'chapter': 2,
#   'verse': 9}: {{'book': 'REV', 'chapter': 5, 'verse': 10}: 56,
#   {'book': 'REV', 'chapter': 1, 'verse': 6}: 63},
#  {'book': 'ISA',
#   'chapter': 61,
#   'verse': 6}: {{'book': '1PE', 'chapter': 2, 'verse': 9}: 53},
#  {'book': 'DEU',
#   'chapter': 7,
#   'verse': 6}: {{'book': '1PE', 'chapter': 2, 'verse': 9}: 82},
#  {'book': 'ISA',
#   'chapter': 53,
#   'verse': 4}: {{'book': '1PE', 'chapter': 2, 'verse': 24}: 94},
#  {'book': 'ACT',
#   'chapter': 20,
#   'verse': 28}: {{'book': '1PE', 'chapter': 2, 'verse': 25}: 51},
#  {'book': 'EZE',
#   'chapter': 34,
#   'verse': 6}: {{'book': '1PE', 'chapter': 2, 'verse': 25}: 62},
#  {'book': 'LUK',
#   'chapter': 15,
#   'verse': 4}: {{'book': '1PE', 'chapter': 2, 'verse': 25}: 57},
#  {'book': 'ISA',
#   'chapter': 53,
#   'verse': 6}: {{'book': '1PE', 'chapter': 2, 'verse': 25}: 108},
#  {'book': 'COL',
#   'chapter': 3,
#   'verse': 19}: {{'book': '1PE', 'chapter': 3, 'verse': 7}: 59},
#  {'book': 'COL',
#   'chapter': 4,
#   'verse': 6}: {{'book': '1PE', 'chapter': 3, 'verse': 15}: 61},
#  {'book': 'JAM',
#   'chapter': 4,
#   'verse': 6}: {{'book': '1PE', 'chapter': 5, 'verse': 5}: 53},
#  {'book': 'JAM',
#   'chapter': 4,
#   'verse': 10}: {{'book': '1PE', 'chapter': 5, 'verse': 6}: 54},
#  {'book': 'PSA',
#   'chapter': 34,
#   'verse': 15}: {{'book': '1PE', 'chapter': 5, 'verse': 7}: 61},
#  {'book': 'LUK',
#   'chapter': 12,
#   'verse': 30}: {{'book': '1PE', 'chapter': 5, 'verse': 7}: 58},
#  {'book': '1SA',
#   'chapter': 30,
#   'verse': 6}: {{'book': '1PE', 'chapter': 5, 'verse': 7}: 63},
#  {'book': 'LUK',
#   'chapter': 12,
#   'verse': 22}: {{'book': '1PE', 'chapter': 5, 'verse': 7}: 69},
#  {'book': 'PSA',
#   'chapter': 56,
#   'verse': 3}: {{'book': '1PE', 'chapter': 5, 'verse': 7}: 93},
#  {'book': 'HEB',
#   'chapter': 13,
#   'verse': 5}: {{'book': '1PE', 'chapter': 5, 'verse': 7}: 74},
#  {'book': '1PE',
#   'chapter': 1,
#   'verse': 13}: {{'book': '1PE', 'chapter': 5, 'verse': 8}: 54},
#  {'book': 'JOB',
#   'chapter': 2,
#   'verse': 2}: {{'book': '1PE', 'chapter': 5, 'verse': 8}: 79},
#  {'book': '2CO',
#   'chapter': 4,
#   'verse': 17}: {{'book': '1PE', 'chapter': 5, 'verse': 10}: 57},
#  {'book': 'LUK',
#   'chapter': 3,
#   'verse': 22}: {{'book': '2PE', 'chapter': 1, 'verse': 17}: 56},
#  {'book': 'MAT',
#   'chapter': 17,
#   'verse': 5}: {{'book': '2PE', 'chapter': 1, 'verse': 17}: 73},
#  {'book': 'MAR',
#   'chapter': 9,
#   'verse': 7}: {{'book': '2PE', 'chapter': 1, 'verse': 17}: 79},
#  {'book': 'MAT',
#   'chapter': 3,
#   'verse': 17}: {{'book': '2PE', 'chapter': 1, 'verse': 17}: 62},
#  {'book': '1TI',
#   'chapter': 2,
#   'verse': 4}: {{'book': '2PE', 'chapter': 3, 'verse': 9}: 67},
#  {'book': 'PRO',
#   'chapter': 28,
#   'verse': 13}: {{'book': '1JO', 'chapter': 1, 'verse': 9}: 72},
#  {'book': 'PSA',
#   'chapter': 32,
#   'verse': 5}: {{'book': '1JO', 'chapter': 1, 'verse': 9}: 80},
#  {'book': 'MAT',
#   'chapter': 6,
#   'verse': 24}: {{'book': '1JO', 'chapter': 2, 'verse': 15}: 54},
#  {'book': 'JAM',
#   'chapter': 4,
#   'verse': 4}: {{'book': '1JO', 'chapter': 2, 'verse': 15}: 80},
#  {'book': '1JO',
#   'chapter': 4,
#   'verse': 4}: {{'book': '1JO', 'chapter': 5, 'verse': 4}: 59},
#  {'book': 'REV',
#   'chapter': 2,
#   'verse': 7}: {{'book': 'REV', 'chapter': 2, 'verse': 17}: 56,
#   {'book': 'REV', 'chapter': 2, 'verse': 11}: 55},
#  {'book': '1JO',
#   'chapter': 1,
#   'verse': 7}: {{'book': 'REV', 'chapter': 7, 'verse': 14}: 56},
#  {'book': 'REV',
#   'chapter': 7,
#   'verse': 14}: {{'book': 'REV', 'chapter': 22, 'verse': 14}: 52},
#  {'book': '1PE',
#   'chapter': 1,
#   'verse': 19}: {{'book': 'REV', 'chapter': 13, 'verse': 8}: 110},
#  {'book': 'REV',
#   'chapter': 13,
#   'verse': 8}: {{'book': 'REV', 'chapter': 17, 'verse': 8}: 58},
#  {'book': 'ISA',
#   'chapter': 25,
#   'verse': 8}: {{'book': 'REV', 'chapter': 21, 'verse': 4}: 56},
#  {'book': 'JOH',
#   'chapter': 12,
#   'verse': 26}: {{'book': 'REV', 'chapter': 22, 'verse': 3}: 58},
#  {'book': 'REV',
#   'chapter': 7,
#   'verse': 15}: {{'book': 'REV', 'chapter': 22, 'verse': 3}: 53},
#  {'book': 'REV',
#   'chapter': 21,
#   'verse': 3}: {{'book': 'REV', 'chapter': 22, 'verse': 3}: 83},
#  {'book': 'MAT',
#   'chapter': 25,
#   'verse': 21}: {{'book': 'REV', 'chapter': 22, 'verse': 3}: 139}}
